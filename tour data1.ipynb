# %%
import requests
import pandas as pd

def search_google_places(query, api_key):
    url = "https://maps.googleapis.com/maps/api/place/textsearch/json"
    params = {
        'query': f"{query} 관광지",   
        'language': 'ko',
        'key': api_key
    }
    res = requests.get(url, params=params)

    if res.status_code != 200:
        print("API 요청 실패:", res.status_code)
        return []

    data = res.json()
    results = data.get('results', [])
    if not results:
        print("검색 결과 없음.")
        return []

    # 결과 출력
    print(f"\n '{query}' 지역의 추천 관광지 리스트 ({len(results)}개):\n")
    for i, place in enumerate(results, 1):
        name = place.get('name', '이름 없음')
        addr = place.get('formatted_address', '주소 없음')
        rating = place.get('rating', '평점 없음')
        print(f"{i}. {name} ({rating})\n  {addr}\n")

    # 엑셀 저장용 데이터프레임 생성
    df = pd.DataFrame([{
        '이름': place.get('name', '이름 없음'),
        '주소': place.get('formatted_address', '주소 없음'),
        '평점': place.get('rating', '평점 없음')
    } for place in results])

    # 엑셀 파일로 저장
    file_name = f"{query}_관광지_리스트.xlsx"
    df.to_excel(file_name, index=False, encoding='utf-8')
    print(f"엑셀 파일 저장 완료: {file_name}")

    return results

# 실행
API_KEY = 'AIzaSyAypFLkcwV_HqxLsTpU8RfkXsYeBG9vetg'
user_input = input("가고 싶은 지역을 입력하세요 : ")
search_google_places(user_input, API_KEY)
# Out:
#  '' 지역의 추천 관광지 리스트 (20개):
#
# 1. 석촌호수 (4.6)
#   대한민국 서울특별시 송파구 잠실6동
#
# 2. 송파관광정보센터 (4.5)
#   대한민국 서울특별시 송파구 송파나루길 206 2층
#
# 3. 강풀만화거리 (3.6)
#   대한민국 서울특별시 강동구 성내동
#
# 4. 율현공원 (4.4)
#   대한민국 서울특별시 강남구 율현동 77-9
#
# 5. 마천공원 (4.1)
#   대한민국 서울특별시 송파구 마천동 11
#
# 6. 남한산성 전승문(북문) (4.4)
#   대한민국 경기도 광주시 남한산성면 산성리 661
#
# 7. 팔당유원지 (4.2)
#   대한민국 경기도 남양주시 와부읍 팔당리
#
# 8. 하남 동사지 (4.1)
#   대한민국 경기도 하남시 춘궁동 457-3
#
# 9. 남한산성도립공원 (4.5)
#   대한민국 경기도 광주시 남한산성로 731
#
# 10. 허브천문공원 (4.5)
#   대한민국 서울특별시 강동구 둔촌동
#
# 11. 물방아관광지 (4.2)
#   대한민국 경기도 광주시 남한산성면 남한산성로 619
#
# 12. 수어장대 (4.4)
#   대한민국 경기도 광주시 남한산성면 산성리 산815-1
#
# 13. 일자산자연공원 (4.4)
#   대한민국 서울특별시 강동구 길동
#
# 14. 남한산성 행궁 (4.4)
#   대한민국 경기도 광주시 남한산성면 남한산성로 784-29
#
# 15. 문정동 로데오거리 (3.9)
#   대한민국 서울특별시 송파구 문정1동
#
# 16. 한성백제박물관 (4.4)
#   대한민국 서울특별시 송파구 위례성대로 71
#
# 17. 일원 에코파크 (4.3)
#   대한민국 서울특별시 강남구 일원동 4-12
#
# 18. 강변테크노마트 하늘공원 (4.4)
#   대한민국 서울특별시 광진구 구의제3동 564-4
#
# 19. 장자호수공원 (4.5)
#   대한민국 경기도 구리시 수택동 687
#
# 20. 구 능내역 (4.1)
#   대한민국 경기도 남양주시 조안면 다산로 566-5
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 48
#      46 API_KEY = 'AIzaSyAypFLkcwV_HqxLsTpU8RfkXsYeBG9vetg'
#      47 user_input = input("가고 싶은 지역을 입력하세요 : ")
# ---> 48 search_google_places(user_input, API_KEY)
#
# Cell In[1], line 40, in search_google_places(query, api_key)
#      38 # 엑셀 파일로 저장
#      39 file_name = f"{query}_관광지_리스트.xlsx"
# ---> 40 df.to_excel(file_name, index=False, encoding='utf-8')
#      41 print(f"엑셀 파일 저장 완료: {file_name}")
#      43 return results
#
# File c:\Users\user\anaconda3\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# TypeError: NDFrame.to_excel() got an unexpected keyword argument 'encoding'

# %%
import requests
import pandas as pd

def search_google_places(query, api_key):
    url = "https://maps.googleapis.com/maps/api/place/textsearch/json"
    params = {
        'query': f"{query} 관광지",   
        'language': 'ko',
        'key': api_key
    }
    res = requests.get(url, params=params)

    if res.status_code != 200:
        print("API 요청 실패:", res.status_code)
        return []

    data = res.json()
    results = data.get('results', [])
    if not results:
        print("검색 결과 없음.")
        return []

    print(f"\n '{query}' 지역의 추천 관광지 리스트 ({len(results)}개):\n")
    for i, place in enumerate(results, 1):
        name = place.get('name', '이름 없음')
        addr = place.get('formatted_address', '주소 없음')
        rating = place.get('rating', '평점 없음')
        print(f"{i}. {name} ({rating})\n  {addr}\n")

    # DataFrame 생성
    df = pd.DataFrame([{
        '이름': place.get('name', '이름 없음'),
        '주소': place.get('formatted_address', '주소 없음'),
        '평점': place.get('rating', '평점 없음')
    } for place in results])

    # 엑셀 파일 저장 (encoding 제거)
    file_name = f"{query}_관광지_리스트.xlsx"
    df.to_excel(file_name, index=False)
    print(f"엑셀 파일 저장 완료: {file_name}")

    return results

# 실행
API_KEY = 'AIzaSyAypFLkcwV_HqxLsTpU8RfkXsYeBG9vetg'
user_input = input("가고 싶은 지역을 입력하세요 : ")
search_google_places(user_input, API_KEY)
# Out:
#  '부산' 지역의 추천 관광지 리스트 (20개):
#
# 1. 감천문화마을 (4.4)
#   대한민국 부산광역시 사하구 감내2로 203
#
# 2. 해동용궁사 (4.4)
#   대한민국 부산광역시 기장군 용궁길 86
#
# 3. 용두산공원 (4.3)
#   대한민국 부산광역시 중구 용두산길 37-55
#
# 4. 오륙도 (4.5)
#   대한민국 부산광역시 남구 용호동 936
#
# 5. 부산시민공원 (4.6)
#   대한민국 부산광역시 부산진구 시민공원로 73
#
# 6. 송도 베이스테이션(해상케이블카) (4.3)
#   대한민국 부산광역시 서구 송도해변로 171
#
# 7. 오륙도 스카이워크 (4.2)
#   대한민국 부산광역시 남구 오륙도로 137
#
# 8. 청사포 (4.4)
#   대한민국 부산광역시 해운대구 중제2동 591-7
#
# 9. 오시리아 해안산책로 (4.6)
#   대한민국 부산광역시 기장군 기장읍 시랑리 62-15
#
# 10. 다이아몬드타워 (부산타워) (4.2)
#   대한민국 부산광역시 중구 용두산길 37-55
#
# 11. BIFF광장 (4.1)
#   대한민국 부산광역시 중구 구덕로 58-1
#
# 12. 만덕레고마을 (3.9)
#   대한민국 부산광역시 북구 만덕제2동 은행나무로23번길 40
#
# 13. 송도용궁구름다리 (4.3)
#   대한민국 부산광역시 서구 암남동 620-53
#
# 14. 흰여울문화마을 (4.4)
#   대한민국 부산광역시 영도구 영선동4가 1043
#
# 15. 깡깡이 예술마을 (3.8)
#   대한민국 부산광역시 영도구 대평북로 36
#
# 16. 솔밭예술마을 (3.6)
#   대한민국 부산광역시 해운대구 우동
#
# 17. 40계단 문화관광테마거리 (3.9)
#   대한민국 부산광역시 중구 중앙동 중앙대로 83
#
# 18. 자갈치시장 (4)
#   대한민국 부산광역시 중구 자갈치해안로 52
#
# 19. 보수동책방골목 (4.1)
#   대한민국 부산광역시 중구 보수동1가
#
# 20. 초량 이바구길 (4.2)
#   대한민국 부산광역시 동구 초량상로 49
#
# 엑셀 파일 저장 완료: 부산_관광지_리스트.xlsx
# [{'business_status': 'OPERATIONAL',
#   'formatted_address': '대한민국 부산광역시 사하구 감내2로 203',
#   'geometry': {'location': {'lat': 35.0973904, 'lng': 129.0105924},
#    'viewport': {'northeast': {'lat': 35.09874022989273,
#      'lng': 129.0119422298928},
#     'southwest': {'lat': 35.09604057010728, 'lng': 129.0092425701073}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#   'icon_background_color': '#13B5C7',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#   'name': '감천문화마을',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 12240,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101474999210773000081">嵐嵐</a>'],
#     'photo_reference': 'ATKogpejIagArS8p7g-U5PD0jdJedcU98DO7qehacTyhQ4Rd6ZnbvDRng4LJGtkU9beyitZLtdd7gfeiCMpuBMZ9OOrgIH-A6coNdX3ADNlIGXGoTGuJ12-U0WizOsgXhm4Lv0K4fDarxAIpFrPjcYb4WfDi2e2zlug0PPGJDlyYm-Yz7P9WgVRDo9hKa54_yzEO2m70yKxhi9BfvODJSPmqC8HI_VXvI49QUir5u2UZhIg5GKZ7js_umqJWVlE4PgayTFXX_xpn_UjmH5f-Tj8dyGL_sGn5BYbQrhByB-ctwRjFCAqnz_M2UWQcFB3Lfy_pgC0u2J0mUYxgh2JENxPf5AuRf6N8wh5VNiolj_TlLJWUoKXc_RBsgbC1QUBhT1aN9zRLpxvIw5RCRHmyCd9XAt9d3e9ICLAvEjUV5IsDZAtTzdVTcBjimk3jiqBqel1bw-BZg1kBLsWZyX7QkskOi1E3Nc2fOeHxViS0-aoFjUIi0W202G-p2hWkH_PDhgdhXoDtYXuO-eF2hcZcajZrDs_hz3ewmNwM5mbosZ2PsK737crV_odFaOb7uMFcSBGUpFA6XZDD',
#     'width': 16320}],
#   'place_id': 'ChIJUToRo7fpaDURo_ZMItcBfpc',
#   'plus_code': {'compound_code': '32W6+X6 부산광역시',
#    'global_code': '8Q7F32W6+X6'},
#   'rating': 4.4,
#   'reference': 'ChIJUToRo7fpaDURo_ZMItcBfpc',
#   'types': ['tourist_attraction', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 30345},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': '대한민국 부산광역시 기장군 용궁길 86',
#   'geometry': {'location': {'lat': 35.1883491, 'lng': 129.2233197},
#    'viewport': {'northeast': {'lat': 35.18969892989272,
#      'lng': 129.2246695298927},
#     'southwest': {'lat': 35.18699927010727, 'lng': 129.2219698701072}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/worship_dharma-71.png',
#   'icon_background_color': '#7B9EB0',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#   'name': '해동용궁사',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 3464,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113584683144389350157">Unique Watts</a>'],
#     'photo_reference': 'ATKogpdv2Kw59smYV88BOi52pAmLj-4BfS6YMhyq4IxEuAceodIT4l9oUGxIJRNj5zRuO3WK9vnkwL2uc1zaQPkVm1oraOhTTrWHDoD6iqvilXrFE6S-JIs6H6pY4hckqhQO6CDmmQDB36s1U_kLdSLddm8u_h5Z94VCnCzV8oc5CqnC2AfzRVqwwNWwz5fBm4-5oH_jvpfSVuzm5P7MOj5AtVI9xI4DnRDASjz1y7mIbGA7v6s6xfuzBaufCDnjlB9-DdRjmnQ182YLJMAGtyM-G4mk267n99zgenVO0uIqpH_KA2cJgAWFtcO6BPyYM9eLV0MB5y3Wvh5kACKZXTo2cyER6sfZDUsa9EARaIcEoJlJ3WHEsKNNbTjraar4gW3RzJ7XlGSKkz9FEd9k973VnWciOU8xtZczmcjUnRGT-gDY7U-6nyHYS9Kd49XG5CyVj03pHcDoIAf3fz29ve-YZFX75JRC2SDxEgy5Qo0ri20hS0ZUADAOW4sIHNSq8sq4YUUAnLu8kyg4phYwofldfhteFLcrg2QRspZWBiPssV2AyBe89m1WbTxuGuNBLADKYyI-CQ',
#     'width': 4618}],
#   'place_id': 'ChIJwabeuxuMaDURXC4Rb21AQaE',
#   'plus_code': {'compound_code': '56QF+88 부산광역시',
#    'global_code': '8Q7F56QF+88'},
#   'rating': 4.4,
#   'reference': 'ChIJwabeuxuMaDURXC4Rb21AQaE',
#   'types': ['tourist_attraction',
#    'place_of_worship',
#    'point_of_interest',
#    'establishment'],
#   'user_ratings_total': 25061},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': '대한민국 부산광역시 중구 용두산길 37-55',
#   'geometry': {'location': {'lat': 35.1006536, 'lng': 129.0326226},
#    'viewport': {'northeast': {'lat': 35.10191157989272, 'lng': 129.03480855},
#     'southwest': {'lat': 35.09921192010728, 'lng': 129.03189395}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/park-71.png',
#   'icon_background_color': '#4DB546',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/tree_pinlet',
#   'name': '용두산공원',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 3024,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/112353283218008655611">Brooks</a>'],
#     'photo_reference': 'ATKogpdXR8OtTZJIRkRT9Ce0lxizYH4h9_Y2I9ZVomXE2T5L41yL7X2YzvI5O2VpIja9es8q7uTNtVdVToLyWjLk51r-u9gdnxMayK4DEcBTLoumz8k8VwcWtlnLHOWj4Bu7dul9xno_LIwNomnHKAFN6t1wiW8CGxqFr01KEvepzWKOl_v4WeyKhbRKTzzt6XLwyp7BgAy8K1r6fwSBc9IO6C78gDisDQZ4mH8anbVy540pet60qet7qFozrPOtt4zHmAu_T_0AUoCQf6_BbDb6PjGzBUSAg4_IzUklkkpS-YPUrD9PgfgH5acTQBL6lKGKafEshE86_YotfiwNVkYaqngiDD0ZnV7xgAoVHr91CFxXJrQyRbfZl7j8OWX2zmPKBGaI13cb6kAsHLMsEqiyxZfo9TKtCxNsBu_C8lVLTH-9fYKl__7W6WXoham1KWj4EKs7ZaoB5GsMmdX92du4netYNC2qtWfzWr5A9cr7FJ8HMzuoqlc9F4tM5GxZPCb4MFHTsy2Z3yt8f4DFjSf4tO52rPEl4Ya-B3_BuKEh562fcuFbtK0AwH4m0fgAdDHk05YMyCs-vVFZPw',
#     'width': 4032}],
#   'place_id': 'ChIJl8gXNgvpaDURP6m_S0gwF74',
#   'plus_code': {'compound_code': '422M+72 부산광역시',
#    'global_code': '8Q7F422M+72'},
#   'rating': 4.3,
#   'reference': 'ChIJl8gXNgvpaDURP6m_S0gwF74',
#   'types': ['park',
#    'tourist_attraction',
#    'point_of_interest',
#    'establishment'],
#   'user_ratings_total': 6210},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': '대한민국 부산광역시 남구 용호동 936',
#   'geometry': {'location': {'lat': 35.0937934, 'lng': 129.1264236},
#    'viewport': {'northeast': {'lat': 35.09514322989272,
#      'lng': 129.1277734298927},
#     'southwest': {'lat': 35.09244357010727, 'lng': 129.1250737701072}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#   'icon_background_color': '#13B5C7',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#   'name': '오륙도',
#   'photos': [{'height': 4032,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/116330021568554614166">H</a>'],
#     'photo_reference': 'ATKogpepEZCjNv2PWMpOo4JGIwZq8kYCeX6384EeB0PPkSj_BZwVtnmGOHG0FPRlVdDAe1RLSG85XDxNcMQALrdHIB5r5D6OscvRwYh-MVw7b6AIUQFkY8n_caQvozeWJNFiI1NOs9Qeg_jk9lS4G1-5vhTySj0S5z66pX1hbH5I9gShU5vsz_WW-0bKl_LAIco7y0TQritLxITYSfmyQ9bleBgq0nUX63xkwjJXGIKBxkaZlr6Qr6GHEZesdyhlPq5zKK7I5n9LagAi68kFIODaTRT3uEJtjZ18YtkHIuxPWvIhrXtGB4sOyQB0ytdF1M6gDGjuKDFgPoq9_9Gsl3srTjSDEgUkf7jhFsZ8S9ST_nTcKTUIZDXCXTxM6tuTpquVmS34hkvSrczESpleM7HRuc8hH7dbhDS13YuAJjH8j8zZ8p2wuiBXrUChWBkVydg2-9v4nEL26gnkgT6hwvllwHdZfN64Raw3PMnmbMDQMfTGoFOGEQNdwUHWbfYcPW4m949St6eitu1YCJRM7B2XDC8Ay96n0D8GxwHL6uvxUvuhKTL1uwtH4kjyAxwEtgxGDRyHGjE-lYAHTg',
#     'width': 3024}],
#   'place_id': 'ChIJX3JhnK3taDURHkdD0FfDqEw',
#   'plus_code': {'compound_code': '34VG+GH 부산광역시',
#    'global_code': '8Q7F34VG+GH'},
#   'rating': 4.5,
#   'reference': 'ChIJX3JhnK3taDURHkdD0FfDqEw',
#   'types': ['tourist_attraction', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 180},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': '대한민국 부산광역시 부산진구 시민공원로 73',
#   'geometry': {'location': {'lat': 35.1681608, 'lng': 129.0573853},
#    'viewport': {'northeast': {'lat': 35.16951062989272,
#      'lng': 129.0587351298927},
#     'southwest': {'lat': 35.16681097010728, 'lng': 129.0560354701073}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/park-71.png',
#   'icon_background_color': '#4DB546',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/tree_pinlet',
#   'name': '부산시민공원',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 1960,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/116439475939255722085">安達琢真</a>'],
#     'photo_reference': 'ATKogpfe6UAw45YnOgGnCw86wn9qqjbyMIpJiF1A6cOwc8yqc8gEpw4IEKB4qrctqc6EcOZj3C2rldUOIDDOmvo8Nx5zdLAHx5rWX2L2lRgtjVL9_58EKycDSLENrczJL8WgiryblDTvERaQTfCSfKRGoXCvJkdprKXP00U8iFHBc_U7iGk3i1PWuOHnx6zn9pTzfN2twtrZIsbvJzuNsjwOn5BbE7VmwZjY3aySbmx86tqF1ntRqqqWzjCPTIoIL1LOy0jCt4KgAgLTgfodtf6emQu_lwsia1n14NJHrZnNp6Yw5ZfoqszfPThobyL4dtWesS1MhwOlWKdfcuQj60QIEcTT8CDY50QIZE89ljCCvKiJEZqqIMTbBnloSIaPbZ_xMmRk2W7BWh6ysIs9beiigK-0wsq__aJorJ0mbitbKdtNucWC3OgAmNFNYh_hzx4n8k4a1IqYPSMSc0_6kF12Ht06mUUdS0uby_xlwnqlUwbWibki8gt2MqbU_0Llugaxftu0il5P4EAfD2BheOwGdo0mufZpTZZEuCN7gl8YCUHmgJpvDbbFa4Ro-R0mhbLr_YmPT9K8',
#     'width': 4032}],
#   'place_id': 'ChIJPbq4_UHraDURSKskEXfxKno',
#   'plus_code': {'compound_code': '5394+7X 부산광역시',
#    'global_code': '8Q7F5394+7X'},
#   'rating': 4.6,
#   'reference': 'ChIJPbq4_UHraDURSKskEXfxKno',
#   'types': ['tourist_attraction',
#    'park',
#    'point_of_interest',
#    'establishment'],
#   'user_ratings_total': 8154},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': '대한민국 부산광역시 서구 송도해변로 171',
#   'geometry': {'location': {'lat': 35.0763876, 'lng': 129.0236199},
#    'viewport': {'northeast': {'lat': 35.07773742989271,
#      'lng': 129.0249697298927},
#     'southwest': {'lat': 35.07503777010727, 'lng': 129.0222700701073}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#   'icon_background_color': '#13B5C7',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#   'name': '송도 베이스테이션(해상케이블카)',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 3024,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109021208910588388939">김동호</a>'],
#     'photo_reference': 'ATKogpcisu3H5oqLdV2UZOmP100vGKjw1K4__8WEN_7dvIV1OGA9GUov88OvIw-OXj51J2X6XMB-VyBal-1MYf-EScoTEaGvpC0i1f_CF3h8ULpUyWp4SqEjdZKzfprX-jKdlT7YUhzNmyRTrmjlcUUK0_tOFM_kvDIseehjqocWmoY9WdtY-xAtejZFHxFVT5CazzQDL_u6zit3yco4QLBDN3Hdg6xSAxFAs7GEc-lL8J1LPp3xwe661Da_b_Q-LeCzOUlts4wem36GzecPM0JooqLDejYZSypDASCttBfKiYBcS1khpwaV2X2HbC4pIeLnb823mMr-HX42Qv8rDV6Ko__83IXs5_C_Tjd-t3KEDcQDvzbqbVEgy9VuxcAuW9V60tqF6x5B--j5U1cMaBmRRFybbTGzAyHt96BOTouQ5Z3v6Vty89fCVlPNNWez13AI29g4d5ypvYvkFgEWrvAH_ywTrsmbI2DBSH9HENCPYVyiqoLKVNAgRdcoSp9RVm1OwNTuvAh32H7yzCiRzcmnYPpQ2AfaZm9-O6mC0k2WfFqUGnbbcOQsSx38m0OAdbD9C3l_wej_',
#     'width': 4032}],
#   'place_id': 'ChIJQehEaUToaDURU7CTL4IJmZY',
#   'plus_code': {'compound_code': '32GF+HC 부산광역시',
#    'global_code': '8Q7F32GF+HC'},
#   'rating': 4.3,
#   'reference': 'ChIJQehEaUToaDURU7CTL4IJmZY',
#   'types': ['tourist_attraction', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 17536},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': '대한민국 부산광역시 남구 오륙도로 137',
#   'geometry': {'location': {'lat': 35.1006767, 'lng': 129.1244009},
#    'viewport': {'northeast': {'lat': 35.10202652989273,
#      'lng': 129.1257507298927},
#     'southwest': {'lat': 35.09932687010728, 'lng': 129.1230510701072}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#   'icon_background_color': '#7B9EB0',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#   'name': '오륙도 스카이워크',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 3024,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115760703912092997543">J J</a>'],
#     'photo_reference': 'ATKogpfxU3vGGGjLs5-JUefWJi6wOxvjlcVWiBp7hluIQ95_KhM_qDlG8NNpqJHsxrmagrkU3-TujRYGdeWhTDiU60w9WI37W3OfxIXaJrX4SxHHkPeqRzsYk3CzZ6UHxvjIVKZTcam_A7FUV-Bu7bTtaYn7k-CwjHbrtJsMjsa9GJvuThjBu1fDdKBtS72vK-mBKGtx_xl3N04OnLq5t80PjKg6jazY2eOA8PnLBp8oirITjiwdORHfNxh7Lhk8SmuxHPhWhNPdrv_I6wcgW8v13K1npFFyW7dEIGx5gX1c86zpxSfrCGmzs0VpqZ_eMoyG4Kn9Xe_58A5_SrtJjOWICC5a7Dtn-lSEwCGn1drHRH1KrL6o8JFx-AEdX2j9zRb-YZ1OoQB14lhKis4HmR1uKD98ky9mMwfJfta4uagCZzmUSFLplWw21KhXPZYy8yMlFgKNJ3Xk8uQIiQXcobMp8WxPMNcGqb5Ps5OjPIRMv_05aMHfp3PewPjsZcTFTYnFfzCYDrceRwDCCsq-QnNXs9EcpFkB657zsofnywd17tgUq57Ped6BpV_TEeQrF1SoAhZ-oQ',
#     'width': 4032}],
#   'place_id': 'ChIJVRLdCsjtaDURcdummQTLnRk',
#   'plus_code': {'compound_code': '442F+7Q 부산광역시',
#    'global_code': '8Q7F442F+7Q'},
#   'rating': 4.2,
#   'reference': 'ChIJVRLdCsjtaDURcdummQTLnRk',
#   'types': ['tourist_attraction',
#    'park',
#    'point_of_interest',
#    'establishment'],
#   'user_ratings_total': 10786},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': '대한민국 부산광역시 해운대구 중제2동 591-7',
#   'geometry': {'location': {'lat': 35.1603874, 'lng': 129.1923456},
#    'viewport': {'northeast': {'lat': 35.16173722989272,
#      'lng': 129.1936954298927},
#     'southwest': {'lat': 35.15903757010727, 'lng': 129.1909957701072}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#   'icon_background_color': '#13B5C7',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#   'name': '청사포',
#   'photos': [{'height': 667,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107199776077578600675">이호상</a>'],
#     'photo_reference': 'ATKogpdLdE5aHAhNwmrBz7txP5Gi-BJeQCpAb-B4GYQgHWX9WdHEz4hC5KXsypjr3MjGKXZyT6KmJSgFjGtTQg3pgt5GhuozBle0_bWWhjS64kSYID6kwY1XLTgkLzYxM1N_vRicNmuq1ltmsycwtjSl5kV9IcAnFZY3cFMSrGEv3WMD7SCIILl03t2rLlkASy8OFsyXFVSWXzknyjFK04MICMopMXxw6R5W94Rw9TO6WpwQWvXhiEu4ZovTLdbKzUzwbbikT46M3hi9qypi2aI0-0lNOQ_776e7k3TNMUBznyBq45jyAClTJN0NB0mVqnAZaDiMMXbU5fuBXzYTMAXm2MhMLWRyZzwwVwZPNLc9EhsxGFHgiPxzftwZ2f9QClzHqj9RuIROUljkzj6PDH5atihbstTbiWZb0XK-QqX6gxVOV_l37CD4fApNHnTV8Ah0GjwcZCcr7UhW1DYeThiITGTXfT-55fzOfr_hU8YdsnChYzUeiTA6DZ3LYlO3Kw_AFuJ_ZKJ3TkPn4HDHLToyb0v9BIRwG-rgNp_SuEkepyAQ6qVYrAwm6tKtfGR7h2NNq8dektHYZOPiVQ',
#     'width': 1000}],
#   'place_id': 'ChIJGcDcTCeNaDURouI8V8vtsX0',
#   'plus_code': {'compound_code': '556R+5W 부산광역시',
#    'global_code': '8Q7F556R+5W'},
#   'rating': 4.4,
#   'reference': 'ChIJGcDcTCeNaDURouI8V8vtsX0',
#   'types': ['tourist_attraction', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 640},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': '대한민국 부산광역시 기장군 기장읍 시랑리 62-15',
#   'geometry': {'location': {'lat': 35.1964237, 'lng': 129.2284464},
#    'viewport': {'northeast': {'lat': 35.19777352989272,
#      'lng': 129.2297962298927},
#     'southwest': {'lat': 35.19507387010728, 'lng': 129.2270965701073}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#   'icon_background_color': '#13B5C7',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#   'name': '오시리아 해안산책로',
#   'opening_hours': {},
#   'photos': [{'height': 1536,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/100895494723874368833">Guide&#39;s traveling</a>'],
#     'photo_reference': 'ATKogpeHoW5CIDFiZzmSKAh6K3Bft2_xmtgLzowX9_J81_CMqKUuJCQUbUEklc2GQsJ-5R5jo-JBIcRMrNOTEVzGJN8rwOLUUy1pcljD6zmlQvmilGkOwah2-MXdk8s5yDL_BVQ03qrf4VzAbnNTd1P4LTDZixHoFCRwI9Mr4GHfD7mIV7yXLJRl529TEKVNwataKzxZI94RTb-NvVzSFh4l-0BjWxaSsSmTb-A62wH3GsYbV_Wjude1i9AfOyRvKVFTA_XiezvacSFhUCGG1x_dM7N0NpYh4zpTc-pan0YWFNMAq9RYFUjlfazWspcuESb-MUaEGhTNM_6kjmkEeU8hWp_s1v8Ry6IMJymvE7apt1JKv3rD-PE3a2ENr27bGIECX6GHv_Nc3LDdUSCzSfj-pGny1il3vHLG9dXM_wXrmc0NGOg9InUkSEKgDBDDAfM4b5LwiPwNTkbgQgjFpHW9jMGiJucBfd0lJOsKBGrO9_UuA6w3kJyaXr0fxsc3IiBErUFtROemM90Wy_FD3ZUVGT50E-iY6bv-LHzb4TU8Akddtqsr5cRNLEHfh1Vz2fcm_lRI4XwrsCtDmg',
#     'width': 2048}],
#   'place_id': 'ChIJu_mBb5-PaDUR01Nt6_PdMJc',
#   'plus_code': {'compound_code': '56WH+H9 부산광역시',
#    'global_code': '8Q7F56WH+H9'},
#   'rating': 4.6,
#   'reference': 'ChIJu_mBb5-PaDUR01Nt6_PdMJc',
#   'types': ['tourist_attraction', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 219},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': '대한민국 부산광역시 중구 용두산길 37-55',
#   'geometry': {'location': {'lat': 35.1011934, 'lng': 129.0323676},
#    'viewport': {'northeast': {'lat': 35.10254322989272,
#      'lng': 129.0337174298927},
#     'southwest': {'lat': 35.09984357010728, 'lng': 129.0310177701073}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#   'icon_background_color': '#7B9EB0',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#   'name': '다이아몬드타워 (부산타워)',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 4032,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/118384257045543964523">James Chia</a>'],
#     'photo_reference': 'ATKogpdkNzsNBzOFY9dFKjE-Jwek5gM1unc3VuGigSyNi22rKrZPGLWSYU6ntC6_ao5IPxMrX-RIN7KskOW3EUKD5f5AGyJIc4XGzdPqmOKzztA5jp73HChaNjX_QkGwPq0ONMxXJMiAllgsH7PyW7vCRjTahE1_2QooPmX2A-fO4ghZ1VAaIEKF2UeErKru9PbhksoLr4tw8jQ1wMqW3eo9tjZ5llCh5zgI9cgvdLIo336Hf2LkMXG-QC9ZWobDn_cNtSYLp7eZorB8p_PVltubrdVPoGSRJR63RePd0Jkig6G0rxWDwSLnycJ3-HLVunVXp2UStf_Z4rmKcPY-owzZOCCN6xz1Uea2EaKtonXpEPkhh0PyQYV8y4EMjjCH9nEjCLhw6vs6sYDdo7TP3xSfiFe2vy6y6NNV-OIUzfsevIkUAcRpkVwNm7VcjEWlH4kcADcJpwpw_tR2vCq-c7IMBJP5jpqGbQ17YZPatGbjJ3VfSqqoPby9NVMaAWN33yizOM7NZPpFQIkU0gzbzjQe03z01J8c4aVIANz2t3UVFLkTYznt1zArepjIjCAWjfyS4a6n2nEk',
#     'width': 3024}],
#   'place_id': 'ChIJq0OD23TpaDURTv9SBp0VWtI',
#   'plus_code': {'compound_code': '422J+FW 부산광역시',
#    'global_code': '8Q7F422J+FW'},
#   'rating': 4.2,
#   'reference': 'ChIJq0OD23TpaDURTv9SBp0VWtI',
#   'types': ['tourist_attraction', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 8938},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': '대한민국 부산광역시 중구 구덕로 58-1',
#   'geometry': {'location': {'lat': 35.098243, 'lng': 129.029212},
#    'viewport': {'northeast': {'lat': 35.09959282989272,
#      'lng': 129.0305618298927},
#     'southwest': {'lat': 35.09689317010728, 'lng': 129.0278621701073}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#   'icon_background_color': '#13B5C7',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#   'name': 'BIFF광장',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 2736,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109847959567199452491">chiatsai C</a>'],
#     'photo_reference': 'ATKogpenPbOptH8ogAtBrgozYBUPixC4YscAKmyOzkrkR_r_-aUshZispj6xBNBRoX5HITNKj8zOxTobTFIQmENA12E-yAHtyVkf1yJduSY6bSZ9ASVusfIpxHWyqbPp-1B7guOIWGqwVGTnXgvEwwBi0mrXRz8pRQNdNgtuszrROFJ-B2O4bI-9ftTj3IRWUI33uhId5ZdHeRvh4toM8XdYGaR7or4xyDaWEIXAnAZ1CyNSPKSEXikcfzyeQ8N4c96sV0pR0IbOV8yQOnORPpukm1XqbX4uZ63CIiB4b55cckEP355HzmI87GWgAE9LjfHhFnr9gworMhOfTpA-UfOMq6_QlmNPWKlJlUYKdbIJAwx9P8IrOeU4r5czxGqvxgnsoN51K2By32uyuJtgvtVjisEU1u9sdF8sK5XRvGCUHG1KUEDk1-TMt9gDRu4BU-pkUWVLDC7oCoVUTe4KgI9YojPvtNSPc0mmfJ4xegbAKUGbs86uqOLdO8-dC6YstiV433kgFipYIKx18LVe3Vl-SHc5JGK9cFhgVcdyILMuWneRlk5yn3qP7NgsmnuTG88_3FKZRy4SbONT6g',
#     'width': 2736}],
#   'place_id': 'ChIJL1scg6DpaDURxXQZg1kWGZ4',
#   'plus_code': {'compound_code': '32XH+7M 부산광역시',
#    'global_code': '8Q7F32XH+7M'},
#   'rating': 4.1,
#   'reference': 'ChIJL1scg6DpaDURxXQZg1kWGZ4',
#   'types': ['tourist_attraction', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 19252},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': '대한민국 부산광역시 북구 만덕제2동 은행나무로23번길 40',
#   'geometry': {'location': {'lat': 35.2076741, 'lng': 129.039815},
#    'viewport': {'northeast': {'lat': 35.20902392989272,
#      'lng': 129.0411648298927},
#     'southwest': {'lat': 35.20632427010727, 'lng': 129.0384651701073}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#   'icon_background_color': '#13B5C7',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#   'name': '만덕레고마을',
#   'opening_hours': {},
#   'photos': [{'height': 3000,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101233167491872474236">청강</a>'],
#     'photo_reference': 'ATKogpfcJ5OyhlyiP6Hvx4o5nzIr6o_qobrHKikMGDkovV1TB886V_yytgfB-xQqDWUirMb77x2cQZjtSoAwbsTCy155XVFPgTYapC2vLUXCK7ooRxKHlP2JIO2ELohungTbi1uhR6Nid1VCwTY6-_MPWlkjnmoazgKfG7BEAVWdZrm6dtrf19g_8c_byK-sgUScFlvvYniaRXcnVeSllyXz8p-xeGB5yWaXQsy6jpFEHW91Z-MFSw8Hyva5TOFZHkMXy4KHZ49-z6LWtwmXM8cqHrCkPMvijqMrlm7IGwoIk-RBAtMj7-AL53ZcBxIILEMq9oRWILAAwnXD13-QbIxWosFF1wxYYFG40vqFv8o5E3WxagrkoJyCMhz3ExUFoVf0_BO0fsFeeo7fFtW7dfq6QCcldVQFsG7oJo2fsjoliKreCKkCrkKcBS8P0y95r8tKN0dXG5Tt3jTEDjsG2SDWciFOJh9WtksVS-vswjHXQe4M-LePdG3kfXPEauyWhMHv_aRVuYydIxA_l0hKIIQekb4CVBueZu7SKX_bzvkFcUpREwR5Y0cRjlMpq1E0ho2wOAHZ1kmdxC1miw',
#     'width': 4000}],
#   'place_id': 'ChIJsShNy8KUaDUR0QuZ81Gksqs',
#   'plus_code': {'compound_code': '625Q+3W 부산광역시',
#    'global_code': '8Q7F625Q+3W'},
#   'rating': 3.9,
#   'reference': 'ChIJsShNy8KUaDUR0QuZ81Gksqs',
#   'types': ['tourist_attraction', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 48},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': '대한민국 부산광역시 서구 암남동 620-53',
#   'geometry': {'location': {'lat': 35.061897, 'lng': 129.022214},
#    'viewport': {'northeast': {'lat': 35.06324682989273,
#      'lng': 129.0235638298927},
#     'southwest': {'lat': 35.06054717010728, 'lng': 129.0208641701072}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#   'icon_background_color': '#13B5C7',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#   'name': '송도용궁구름다리',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 3000,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107064431797194683909">김철수 (Jin)</a>'],
#     'photo_reference': 'ATKogpdFs7hEWKSoH0GZIwJgl9SKcWiWHbDaj2xWJ2wzVNRfDWvnIHbN3cg_3PJJzN70SPZSDoJnUZqw31cJ5fVvH6t-MzqsQGiFxoeY7zljTP7ig7qrfeAsE9JtDofIOPrIy2NPsjChHjV9507KRNDxYCefDIcp2VWKlUMQMYTigu5F80NcDzvsy-7KzX79XpAWK8YExoC_5zY33L8sDGSeQZyro9VxBt7KIzRmIl744cdmxqz6dNkM8kyrYNOvUvyrepFQEhf0OtTtX36eUwYLtYx0X-gIO0jXyZdo7tVeMH7C2szkvJGRAci11UjZTps6i4OGcD9zlWTXJe7eU1t1rjep-2-Ram4OjSFsL3wdSDqTQ9vMWnuvacgqLWD7M6jk4sUztkFzrGdmaoy2z9eb_ACveUCUklcSVnmcp9rG3chsWgGNF-2fL2oCu2dyifzzuenh2VqpBAefDZG1utTe-3V2a4siruBpezIB-Lv1cSa_TiGpflToYTeR2uQh1zbL_HMZYUkgvm2uj43Fb31IcrhcNI3CBiserDeealxd1BdPftnY5c4_5CMSqzCSYbW8v3MO2Fno',
#     'width': 4000}],
#   'place_id': 'ChIJowcfhcjpaDUR2bVHuhHfH-Q',
#   'plus_code': {'compound_code': '326C+QV 부산광역시',
#    'global_code': '8Q7F326C+QV'},
#   'rating': 4.3,
#   'reference': 'ChIJowcfhcjpaDUR2bVHuhHfH-Q',
#   'types': ['tourist_attraction', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 1156},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': '대한민국 부산광역시 영도구 영선동4가 1043',
#   'geometry': {'location': {'lat': 35.0782798, 'lng': 129.0453198},
#    'viewport': {'northeast': {'lat': 35.07962962989272,
#      'lng': 129.0466696298927},
#     'southwest': {'lat': 35.07692997010727, 'lng': 129.0439699701072}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#   'icon_background_color': '#13B5C7',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#   'name': '흰여울문화마을',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 3468,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106118861477881507396">허금열</a>'],
#     'photo_reference': 'ATKogpeGRLuRzqp_B65YZsnDtMjSggM2epbT0ZxksPjZg5m0VoojCpBjg7iBq52DFIzSg3IsSz-piriEmVkB0JH_e-Q906n_UKodaKAdNG77wxcCA1XhIiVRAmXInViqCxn4EVwye2U334vGX5C8FZMEkicRQKH-7xjcco6enrRtcLenEc3VJXsvNJ-IikYI4iL3BJvN-W74mt-64lVkczVZRMiVtIJmMj_XH8SY0vXU7L0RUknohYJ2VNw7Kj9wTNp1lZruFO4INd85_l2oUkXHOBjS5kXiKsNvgsRwy8hhWT6BxUTNodLFE7FulQxVcdcbUHOnT8BkafDjXktkpPqJ7aogtL9OXQeDLatiFzZrSozCX55-5lzEvBeLPAYuasah6cu1Hvesahy8fkoMTTmXY6H9uUhexFnWrAWXuAKsUGXO-iBOd1QhS6J2YnKKAC4mINtqO8dEFQ2lif5wPEz3htAgIbz27s9rZYrXVhtPmguHqnPrTCdDyQs3qPe760HTEpRsWNbDLdFbKpc79qLQ2Vb8-56bkYFnniuKk1pcP99i-IXO5VSU67tpua54PlBBh88Jo2wFEapfPg',
#     'width': 4624}],
#   'place_id': 'ChIJseGsfh7paDURigYilgTVojA',
#   'plus_code': {'compound_code': '32HW+84 부산광역시',
#    'global_code': '8Q7F32HW+84'},
#   'rating': 4.4,
#   'reference': 'ChIJseGsfh7paDURigYilgTVojA',
#   'types': ['tourist_attraction', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 8176},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': '대한민국 부산광역시 영도구 대평북로 36',
#   'geometry': {'location': {'lat': 35.0918144, 'lng': 129.0338503},
#    'viewport': {'northeast': {'lat': 35.09316422989272,
#      'lng': 129.0352001298927},
#     'southwest': {'lat': 35.09046457010728, 'lng': 129.0325004701073}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#   'icon_background_color': '#13B5C7',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#   'name': '깡깡이 예술마을',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 3120,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108177986610589548939">Kee chun RYU</a>'],
#     'photo_reference': 'ATKogpdlaOsTjLDv3F-Ne4sAIh5JYaJI2MtUuOEtNOEv1B0y6DUnMccJpTBdk-dspWTSskZmAD34xzlPHMeIVlU1ngqWRtBzpVFEQ_WDv4wX4VoX9_1H31HvFq1kNGye__TjId0JJe0IWPtoLz6Dn5Q_cNpfn8lH0gquwWlHz94ecXd1UatjYUucy2YgY0XjAFYn8dwDprOh5sMpYB0dLqALKQtrH9uDxULzkVw69ijYya0QBvbgr5ajGcwcNZrAwJ6U8wCadJrgT0aCxgMBr-sS5pAZ2rvAp9d5tlqpHzqqbVdjK09346ZCKxjoIDQF9WfkoFYXqZ8apR0vx1waufCS5h0hYZPgmo1XFkHIrS6XdHAh99ZaFi6c6mWQr--mkr7NI0Ts6z_PJ3ou_gqC-1ylMR07qvmPaICTL7bTqB3zppy0rOmK9qEtNfmNIQTN19k9e2jr4HDU_duwMlgqyppi4-4xJWmNL0uaQtvm_O4-T3FMFY3tFnkQZiv4yWeRRlR6k2mISfFHwFl7nL6mFcAU0lGk0vKf8UjujPjOZfQbA34ySMAz4QN19B9le1pLPIvMdP2IO_x6',
#     'width': 4160}],
#   'place_id': 'ChIJ7du2yAjpaDUR0cpem-VPoVU',
#   'plus_code': {'compound_code': '32RM+PG 부산광역시',
#    'global_code': '8Q7F32RM+PG'},
#   'rating': 3.8,
#   'reference': 'ChIJ7du2yAjpaDUR0cpem-VPoVU',
#   'types': ['tourist_attraction', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 301},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': '대한민국 부산광역시 해운대구 우동',
#   'geometry': {'location': {'lat': 35.1646875, 'lng': 129.1623125},
#    'viewport': {'northeast': {'lat': 35.16603732989272,
#      'lng': 129.1636623298927},
#     'southwest': {'lat': 35.16333767010727, 'lng': 129.1609626701072}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#   'icon_background_color': '#13B5C7',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#   'name': '솔밭예술마을',
#   'opening_hours': {},
#   'photos': [{'height': 3024,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/100783571871864732625">Shinae Yu</a>'],
#     'photo_reference': 'ATKogpfdWeKvAWKMRnTRU39tmQrOpXCbTfIJ-DruXmDFhJGQvzusz-G_DCMzsQo8Rgl_sWwjAytI_TlQ-dx7DJIOxmG22kfHiSg4-mAAR2zUh_TKLjoXew6xlcgAvoqEqhFGFS4yyX3lU6XtUp-D9Z4du-5D_wlMa9mN8OEVXZjaFS6VIghGkRdjoo3w2Y98CdmVeXeHOXnhdA7ACBtHxYfe93KUSK2aGrUeYQdaJE3RK6OuFNhBB6OG5MXyHrmIGYS9p2ll-pnZeyfBieeyUjiz7WouWbLLkHTghlv1m8KfSZ2vmWlo9D1gROOIJ0QG9dnnt9mHnSVTRpwIZRY1zVeEN1U44dhIOVafpWOtjjSqCuWaHVGxTmtWYrqesQk7nJBdMkX5afmQ6GHNp4WhiFzYlyqfhUG8tVF2pyaY8ql33XNfpI_fPOur28X01TZ-1FldB0szZdTkoVE8SwuLUSobtpWmkzBtxPCvQHfyPV6hY0n3F1iFwpm8Zhtmzmsqg3iGPb5qP4ZVwdJrlCilyDrWE4O0jXfv7n5Gugvt5fiqEV13nDX2ZE-7uN_VT1xRxud_dBJUvl3p',
#     'width': 4032}],
#   'place_id': 'ChIJ7-qsq2eNaDURJHZWKdX0m3o',
#   'plus_code': {'compound_code': '5576+VW 부산광역시',
#    'global_code': '8Q7F5576+VW'},
#   'rating': 3.6,
#   'reference': 'ChIJ7-qsq2eNaDURJHZWKdX0m3o',
#   'types': ['tourist_attraction', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 38},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': '대한민국 부산광역시 중구 중앙동 중앙대로 83',
#   'geometry': {'location': {'lat': 35.1039553, 'lng': 129.0347152},
#    'viewport': {'northeast': {'lat': 35.10530512989271,
#      'lng': 129.0360650298927},
#     'southwest': {'lat': 35.10260547010727, 'lng': 129.0333653701073}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#   'icon_background_color': '#13B5C7',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#   'name': '40계단 문화관광테마거리',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 3024,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/100948485700978547373">Ann J</a>'],
#     'photo_reference': 'ATKogpdkj2q2ihS-qNaaheDmsmovAjumCkSt73HY35X4GcFBQcv3j-LiN-yvorsOsK05FRuzkcIaBbsaD7ebpYsdn4p1NK7L-no3IBdYMEFYmvyrMkA-ian67bb1vVeMNMllfV1zUkyRqDQgz5otCjFHBBzppDza4MAcwlF31j208tTGUo9mcamx0nBCZAeSCdP1PTRKgiTQ-S3e-OVJ241B8p5P_1pWkTrYhOKyUsP42RO8c2r2a3kaYSKbjq_Y_tPK1qb8gAdgsZlxP5Y72pXvXnavo25zmcwiFC71wofuCI8d4lsw-CyzrqyYLbX_djtw7CYwfrBuEPv_Xh12l8NT0_LwIsnkwFGvxnoaEJmpxOy4fMJJzKH1SKES2UaFkSRGqpCj5XGrQi8PjW1ULtC8XSxqJblnOdpkdkSVq8u5FuarWvDj2tsD45_5AXjwVjeTiBODXQ-BSWn0F6zY9IBBUFkUtPr8YnLok1NpBgn_OTn8-SsHzU8kInLROwC1JoOiLlj1QFrbEDrCmurSIArK2fUtP7qgv2tTx6vgESoIuFaM4Xnhgu1hWaMRWGH43ncf_6CtRTnW-eOJ9g',
#     'width': 4032}],
#   'place_id': 'ChIJQVH2anHpaDURqC0UchLoQL4',
#   'plus_code': {'compound_code': '423M+HV 부산광역시',
#    'global_code': '8Q7F423M+HV'},
#   'rating': 3.9,
#   'reference': 'ChIJQVH2anHpaDURqC0UchLoQL4',
#   'types': ['tourist_attraction', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 1769},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': '대한민국 부산광역시 중구 자갈치해안로 52',
#   'geometry': {'location': {'lat': 35.0966339, 'lng': 129.0307965},
#    'viewport': {'northeast': {'lat': 35.09798372989272,
#      'lng': 129.0321463298928},
#     'southwest': {'lat': 35.09528407010727, 'lng': 129.0294466701073}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#   'icon_background_color': '#4B96F3',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet',
#   'name': '자갈치시장',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 4248,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108371475659379163418">김근원</a>'],
#     'photo_reference': 'ATKogpem_Q40rpEK8AWo_j4LzMpIVloRg8OGplfJX4_o_8-XIu2lF7JXPwOhAwAuuW7e12MZjMiLhb883sV_Io3gMzMZiPzotjfecu4GrDNg8hy5Idd6b7EiV4Rt8XO8JIYjiDpU8geOqmP_LP-EL2YNX22bG5x0yKBCuaR2W1VcIO5hq1u7n78QVv1E0D-tpxp6Oqd3hZQBFGXckCK7mwHyGvPdYmJeOEsdcrNzmURL8kG73iDzksSrO_G1af65by-EYsEyLdRHU5yRdtvQCMlDrrqtjDe4tfxM9555vSh_AznksSGYUugSHEnGCwR2DXFrc3xqA98dZ2GhjAFeEo-Pjv6WGg2rcf4polDWPjc-BaWbk1E2Y2IIQmlI-IA_cn-zAqIQwMv0M4ZFF8V4lsNAwGJBSlP8sDtBfAQD7plmRppWB9xBeLbSNUsIknnG8LVdlDLMWb_gTe_uYWDnIkiuBdW29bpxauIkwlbIhwT8Al5UzKAgEIibSHAMfGqdFCnKkieWVqnXP_YNo98RhvPH4NNIFv8JLql-_pO52uvb0RreNmEHVUOjznXAmL4QsK1ir2vVy2T7TIPM2g',
#     'width': 5664}],
#   'place_id': 'ChIJudkrFArpaDURbbCzajeQs0c',
#   'plus_code': {'compound_code': '32WJ+M8 부산광역시',
#    'global_code': '8Q7F32WJ+M8'},
#   'rating': 4,
#   'reference': 'ChIJudkrFArpaDURbbCzajeQs0c',
#   'types': ['tourist_attraction',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   'user_ratings_total': 26032},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': '대한민국 부산광역시 중구 보수동1가',
#   'geometry': {'location': {'lat': 35.1031252, 'lng': 129.0274609},
#    'viewport': {'northeast': {'lat': 35.10447502989273,
#      'lng': 129.0288107298927},
#     'southwest': {'lat': 35.10177537010728, 'lng': 129.0261110701073}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#   'icon_background_color': '#13B5C7',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#   'name': '보수동책방골목',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 3024,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106295264277843986320">Okhwa Kyoung</a>'],
#     'photo_reference': 'ATKogpdy19a7odQnGpKw8O_8wSTI_h1OFk07fGxLNOtcgPNZZGMizEJWBAMYED5LtMqzNgZ3mP4XIOwqvNnRFi1yf0-Onls9sCZETMKfnKsK5DKoFaUeptOyblYCW32qWd8th7mByhfvCpUvL3vEtuWpjCSFZ2jfZ9DIY3LiaZp7pZysM-Sir5YSMaghG1v_LO217bxD_wVqrxR7H1aU3FH6aKnqcmb3SLY_DHB2D4Ez7SKE20ovKpWkDYADESR9YgP3CobemRbNJKnON0mceTlKtTKrrwU_R8VxXu36hutZaUwhF57f4XxDHKpoDj8zNdnMX-ikWmWbCNUyQnjHwl_3brBYFgAEYrBZvVrJOM-_yf-Ac7madWDnpKCjk4NalH8VdkqK1PX37mND9lv55spZ3Eguv9h2zodEFX-gT_4YVB9pl8BgW3s96uLiOiyTobl7FDA0ggx69clmMqR_iUGP-lWkdMeKjf-QBq9njoAo093R2ZU0id5JcdwKaL-3nFWWqQZvnJkbxS1kbIsePnsBj8BPSnP6dByogTe8Lz5VswUgqCj5woal1CLv4fvsI8dbp7aPoTFn',
#     'width': 4032}],
#   'place_id': 'ChIJZVDztJ_paDURgAwXDlRwUZo',
#   'plus_code': {'compound_code': '423G+7X 부산광역시',
#    'global_code': '8Q7F423G+7X'},
#   'rating': 4.1,
#   'reference': 'ChIJZVDztJ_paDURgAwXDlRwUZo',
#   'types': ['tourist_attraction', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 3610},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': '대한민국 부산광역시 동구 초량상로 49',
#   'geometry': {'location': {'lat': 35.1168609, 'lng': 129.036664},
#    'viewport': {'northeast': {'lat': 35.11821072989272,
#      'lng': 129.0380138298927},
#     'southwest': {'lat': 35.11551107010727, 'lng': 129.0353141701073}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#   'icon_background_color': '#13B5C7',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#   'name': '초량 이바구길',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 3456,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117224091329874088625">Mooseong Kim</a>'],
#     'photo_reference': 'ATKogpdROo_yPADX8jMo6M7lTkW-6BPhqzAAqMt3AApHEjv5g1oYPK1ZDRWkgEKIo6BKwwuIDwVDhGuQIVPatti9iptOts23V4CSksmsNAN9LH9hXhxe3s8mCEMhabEoKvitC6J3W_AmTZRQFPcFDGUFguLhJuOkIh9F72Ar0gCZlm_Z-mM7cCjr7Dcae5hXggmHLwKRNY5qNMJOHmzg5iOZFeyr_BHn82gQyM3P68ZtoTj_ToI4Q_QuPKj0GNnAKNptmqLH9a9E2Om4pWgykqpNvuyazleB48WOOdV_ZOoUXvcQp4u7FnXF2QriCP7SciJ-sel6l_zjQVIQVrxHjhzguGUxDq3tSUO-m8qyFlPYOwnpdpJ_HU8AXcgeHBJ_9_jX7Oktw3T7rRNzBj6HpR4z-LnPPoM-DeNDgdKGxrnX4Vbf9pTPPfi8gdUkIyBZCzkEFPZDHfk5lNiyEr-Mm-wIKTu1eIRA0Tx10z3-oW4jShEi6rhvjkkU7fugBzSTP57PIx9-CiEbGQHCmXEycjcTJQ-yjSJhvWG4_URBnwV9p0eToMoH_gXil9HnBYA1Rl112kHTQNHw',
#     'width': 4608}],
#   'place_id': 'ChIJfU00h33paDURgGZRLHYvXvs',
#   'plus_code': {'compound_code': '428P+PM 부산광역시',
#    'global_code': '8Q7F428P+PM'},
#   'rating': 4.2,
#   'reference': 'ChIJfU00h33paDURgGZRLHYvXvs',
#   'types': ['tourist_attraction', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 941}]

# %%
import requests
import pandas as pd

# 1️⃣ 구글 플레이스 API - 관광지 검색
def search_google_places(query, api_key):
    url = "https://maps.googleapis.com/maps/api/place/textsearch/json"
    params = {
        'query': f"{query} 관광지",
        'language': 'ko',
        'key': api_key
    }
    res = requests.get(url, params=params)
    if res.status_code != 200:
        print("API 요청 실패:", res.status_code)
        return []
    return res.json().get('results', [])

# 2️⃣ 카카오 로컬 API - 맛집 검색
def search_kakao_restaurants(lat, lon, kakao_key):
    url = "https://dapi.kakao.com/v2/local/search/keyword.json"
    headers = {"Authorization": f"KakaoAK {kakao_key}"}
    params = {
        'query': '맛집',
        'x': lon,
        'y': lat,
        'radius': 3000,  # 3km 반경
        'size': 10
    }
    res = requests.get(url, headers=headers, params=params)
    if res.status_code != 200:
        print("카카오 API 실패:", res.status_code)
        return []
    return res.json().get('documents', [])

# 3️⃣ 통합 실행
def main():
    GOOGLE_KEY = 'AIzaSyAypFLkcwV_HqxLsTpU8RfkXsYeBG9vetg'
    KAKAO_KEY = '7659c6478eec0d513fc4881bbcd44c2c'
    user_input = input("가고 싶은 지역을 입력하세요 : ")

    # 관광지 검색
    places = search_google_places(user_input, GOOGLE_KEY)
    if not places:
        print("관광지를 찾을 수 없습니다.")
        return

    all_data = []

    for place in places:
        name = place.get('name')
        addr = place.get('formatted_address')
        rating = place.get('rating', 'N/A')
        lat = place['geometry']['location']['lat']
        lon = place['geometry']['location']['lng']

        # 관광지별 근처 맛집 검색
        restaurants = search_kakao_restaurants(lat, lon, KAKAO_KEY)

        for r in restaurants:
            all_data.append({
                '관광지명': name,
                '관광지주소': addr,
                '관광지평점': rating,
                '맛집명': r.get('place_name'),
                '맛집주소': r.get('address_name'),
                '맛집거리(m)': r.get('distance'),
                '맛집전화번호': r.get('phone')
            })

    # 엑셀 저장
    df = pd.DataFrame(all_data)
    file_name = f"{user_input}_관광지_맛집리스트.xlsx"
    df.to_excel(file_name, index=False)
    print(f"엑셀 파일 저장 완료: {file_name}")

# 실행
if __name__ == "__main__":
    main()
# Out:
# 엑셀 파일 저장 완료: 전국_관광지_맛집리스트.xlsx

# %%
import requests
import pandas as pd

def search_google_places(query, api_key):
    url = "https://maps.googleapis.com/maps/api/place/textsearch/json"
    params = {
        'query': query + " 관광지",
        'language': 'ko',
        'key': api_key
    }
    res = requests.get(url, params=params)
    if res.status_code != 200:
        print("Google API 실패:", res.status_code)
        return []
    return res.json().get('results', [])

def search_kakao_restaurants(lat, lon, api_key, page=1):
    url = "https://dapi.kakao.com/v2/local/search/category.json"
    headers = {"Authorization": api_key}
    params = {
        'category_group_code': 'FD6',
        'x': str(lon),
        'y': str(lat),
        'radius': 3000,
        'page': page,
        'size': 15,
        'sort': 'distance'
    }
    res = requests.get(url, headers=headers, params=params)
    if res.status_code != 200:
        print("카카오 API 실패:", res.status_code)
        print("응답 내용:", res.text)
        return []

    if page == 1:
        print(" 전체 맛집 수 (API 기준):", res.json()['meta']['total_count'])
    return res.json().get('documents', [])

# === 실행 ===
GOOGLE_API_KEY = 'AIzaSyAypFLkcwV_HqxLsTpU8RfkXsYeBG9vetg'
KAKAO_API_KEY = 'KakaoAK 7659c6478eec0d513fc4881bbcd44c2c'

region = input("여행 지역을 입력하세요 (예: 강원도): ")
places = search_google_places(region, GOOGLE_API_KEY)

if not places:
    print("해당 지역의 관광지를 찾을 수 없습니다.")
    exit()

print(f"\n'{region}'의 추천 관광지 목록:")
for i, p in enumerate(places, 1):
    print(f"{i}. {p['name']} - {p.get('formatted_address', '주소 없음')}")

idx = int(input("\n몇 번 관광지를 선택할까요? ")) - 1
selected = places[idx]
lat = selected['geometry']['location']['lat']
lon = selected['geometry']['location']['lng']
print(f"\n선택한 관광지: {selected['name']}")

restaurants = search_kakao_restaurants(lat, lon, KAKAO_API_KEY)

# ✅ 유효한 데이터만 필터링
valid_restaurants = [
    r for r in restaurants
    if r.get('place_name') and r.get('road_address_name')
]

if not valid_restaurants:
    print("표시할 수 있는 맛집 정보가 없습니다.")
else:
    print("\n 주변 맛집 목록:")
    for i, r in enumerate(valid_restaurants, 1):
        print(f"{i}. {r['place_name']} ({r['distance']}m)\n   {r['road_address_name']} / ☎ {r.get('phone', '정보 없음')}")

    # ✅ 엑셀 저장
    df = pd.DataFrame([{
        '맛집명': r['place_name'],
        '주소': r['road_address_name'],
        '거리(m)': r['distance'],
        '전화번호': r.get('phone', '정보 없음')
    } for r in valid_restaurants])

    file_name = f"{selected['name']}_맛집리스트.xlsx"
    df.to_excel(file_name, index=False)
    print(f"\n엑셀 파일 저장 완료: {file_name}")
# Out:
# '부산'의 추천 관광지 목록:
# 1. 감천문화마을 - 대한민국 부산광역시 사하구 감내2로 203
# 2. 해동용궁사 - 대한민국 부산광역시 기장군 용궁길 86
# 3. 용두산공원 - 대한민국 부산광역시 중구 용두산길 37-55
# 4. 오륙도 - 대한민국 부산광역시 남구 용호동 936
# 5. 부산시민공원 - 대한민국 부산광역시 부산진구 시민공원로 73
# 6. 송도 베이스테이션(해상케이블카) - 대한민국 부산광역시 서구 송도해변로 171
# 7. 오륙도 스카이워크 - 대한민국 부산광역시 남구 오륙도로 137
# 8. 청사포 - 대한민국 부산광역시 해운대구 중제2동 591-7
# 9. 오시리아 해안산책로 - 대한민국 부산광역시 기장군 기장읍 시랑리 62-15
# 10. 다이아몬드타워 (부산타워) - 대한민국 부산광역시 중구 용두산길 37-55
# 11. BIFF광장 - 대한민국 부산광역시 중구 구덕로 58-1
# 12. 만덕레고마을 - 대한민국 부산광역시 북구 만덕제2동 은행나무로23번길 40
# 13. 송도용궁구름다리 - 대한민국 부산광역시 서구 암남동 620-53
# 14. 흰여울문화마을 - 대한민국 부산광역시 영도구 영선동4가 1043
# 15. 깡깡이 예술마을 - 대한민국 부산광역시 영도구 대평북로 36
# 16. 솔밭예술마을 - 대한민국 부산광역시 해운대구 우동
# 17. 40계단 문화관광테마거리 - 대한민국 부산광역시 중구 중앙동 중앙대로 83
# 18. 자갈치시장 - 대한민국 부산광역시 중구 자갈치해안로 52
# 19. 보수동책방골목 - 대한민국 부산광역시 중구 보수동1가
# 20. 초량 이바구길 - 대한민국 부산광역시 동구 초량상로 49
#
# 선택한 관광지: 감천문화마을
#  전체 맛집 수 (API 기준): 3978
#
#  주변 맛집 목록:
# 1. 웅이네 (23m)
#    부산 사하구 옥천로 125 / ☎ 010-8582-9563
# 2. 머거방 (42m)
#    부산 사하구 감내2로 198 / ☎
# 3. 찹쌀씨앗호떡 (137m)
#    부산 사하구 감내2로 178 / ☎
# 4. 실비집 (150m)
#    부산 사하구 감내2로 176 / ☎ 051-205-2782
# 5. 할매전통돼지껍데기 (179m)
#    부산 서구 아미로 14 / ☎ 051-254-7406
# 6. 김앤서 (180m)
#    부산 사하구 감내2로 132 / ☎
# 7. 감천쫀드기 (181m)
#    부산 사하구 감내2로 136 / ☎
# 8. 감천제빵소 (197m)
#    부산 사하구 감내2로 145 / ☎
# 9. 샤르르르 (200m)
#    부산 사하구 감내2로 143-2 / ☎
# 10. 츄릅젤라또 (200m)
#    부산 사하구 감내2로 143-2 / ☎
# 11. 감내비빔밥 (210m)
#    부산 사하구 감내2로 159 / ☎ 070-8111-5539
# 12. 감내분식 (211m)
#    부산 사하구 감내2로 159 / ☎ 070-8111-5529
# 13. 더플레이트 (256m)
#    부산 사하구 감내2로 113 / ☎ 051-207-7592
# 14. 감천소머리곰탕 (261m)
#    부산 사하구 감내1로 173 / ☎ 010-4583-6866
# 15. 문화반점 (270m)
#    부산 사하구 감내1로 174 / ☎ 051-291-0150
#
# 엑셀 파일 저장 완료: 감천문화마을_맛집리스트.xlsx

# %%
import requests
import pandas as pd

def search_google_places(query, api_key):
    url = "https://maps.googleapis.com/maps/api/place/textsearch/json"
    params = {
        'query': query + " 관광지",
        'language': 'ko',
        'key': api_key
    }
    res = requests.get(url, params=params)
    if res.status_code != 200:
        print("Google API 실패:", res.status_code)
        return []
    return res.json().get('results', [])

def search_kakao_restaurants(lat, lon, api_key, pages=3):
    url = "https://dapi.kakao.com/v2/local/search/category.json"
    headers = {"Authorization": api_key}
    all_restaurants = []

    for page in range(1, pages + 1):
        params = {
            'category_group_code': 'FD6',   
            'x': str(lon),
            'y': str(lat),
            'radius': 3000,                
            'size': 15,
            'page': page,
            'sort': 'distance'
        }
        res = requests.get(url, headers=headers, params=params)
        if res.status_code != 200:
            print("카카오 API 실패:", res.status_code)
            print("응답 내용:", res.text)
            continue
        all_restaurants += res.json().get('documents', [])

    return all_restaurants

# === 실행 ===
GOOGLE_API_KEY = 'AIzaSyAypFLkcwV_HqxLsTpU8RfkXsYeBG9vetg'
KAKAO_API_KEY = 'KakaoAK 7659c6478eec0d513fc4881bbcd44c2c'

region = input("여행 지역을 입력하세요 (예: 강원도): ")
places = search_google_places(region, GOOGLE_API_KEY)

if not places:
    print("해당 지역의 관광지를 찾을 수 없습니다.")
    exit()

print(f"\n '{region}'의 추천 관광지 목록:")
for i, p in enumerate(places, 1):
    print(f"{i}. {p['name']} - {p.get('formatted_address', '주소 없음')}")

idx = int(input("\n몇 번 관광지를 선택할까요? ")) - 1
selected = places[idx]
lat = selected['geometry']['location']['lat']
lon = selected['geometry']['location']['lng']
print(f"\n 선택한 관광지: {selected['name']}")

restaurants = search_kakao_restaurants(lat, lon, KAKAO_API_KEY, pages=5)
print(f"\n 전체 받은 맛집 수: {len(restaurants)}")

valid_restaurants = [
    r for r in restaurants
    if r.get('place_name')
]

# 거리순 정렬 후 Top 10
sorted_restaurants = sorted(valid_restaurants, key=lambda x: int(x.get('distance', 99999)))[:10]

print("\n 주변 맛집 Top 10:")
for i, r in enumerate(sorted_restaurants, 1):
    print(f"{i}. {r['place_name']} ({r.get('distance', '?')}m)")
    print(f"    {r.get('road_address_name', '주소 없음')} / ☎ {r.get('phone', '정보 없음')}")
    print(f"    카카오맵: {r.get('place_url', '없음')}\n")

# ✅ 엑셀로 저장
df = pd.DataFrame([{
    '맛집명': r['place_name'],
    '주소': r.get('road_address_name', '주소 없음'),
    '거리(m)': r.get('distance', '?'),
    '전화번호': r.get('phone', '정보 없음'),
    '카카오맵 URL': r.get('place_url', '없음')
} for r in sorted_restaurants])

file_name = f"{selected['name']}_맛집Top10.xlsx"
df.to_excel(file_name, index=False)
print(f"\n엑셀 파일 저장 완료: {file_name}")
# Out:
#  '부산'의 추천 관광지 목록:
# 1. 감천문화마을 - 대한민국 부산광역시 사하구 감내2로 203
# 2. 해동용궁사 - 대한민국 부산광역시 기장군 용궁길 86
# 3. 용두산공원 - 대한민국 부산광역시 중구 용두산길 37-55
# 4. 오륙도 - 대한민국 부산광역시 남구 용호동 936
# 5. 부산시민공원 - 대한민국 부산광역시 부산진구 시민공원로 73
# 6. 송도 베이스테이션(해상케이블카) - 대한민국 부산광역시 서구 송도해변로 171
# 7. 오륙도 스카이워크 - 대한민국 부산광역시 남구 오륙도로 137
# 8. 청사포 - 대한민국 부산광역시 해운대구 중제2동 591-7
# 9. 오시리아 해안산책로 - 대한민국 부산광역시 기장군 기장읍 시랑리 62-15
# 10. 다이아몬드타워 (부산타워) - 대한민국 부산광역시 중구 용두산길 37-55
# 11. BIFF광장 - 대한민국 부산광역시 중구 구덕로 58-1
# 12. 만덕레고마을 - 대한민국 부산광역시 북구 만덕제2동 은행나무로23번길 40
# 13. 송도용궁구름다리 - 대한민국 부산광역시 서구 암남동 620-53
# 14. 흰여울문화마을 - 대한민국 부산광역시 영도구 영선동4가 1043
# 15. 깡깡이 예술마을 - 대한민국 부산광역시 영도구 대평북로 36
# 16. 솔밭예술마을 - 대한민국 부산광역시 해운대구 우동
# 17. 40계단 문화관광테마거리 - 대한민국 부산광역시 중구 중앙동 중앙대로 83
# 18. 자갈치시장 - 대한민국 부산광역시 중구 자갈치해안로 52
# 19. 보수동책방골목 - 대한민국 부산광역시 중구 보수동1가
# 20. 초량 이바구길 - 대한민국 부산광역시 동구 초량상로 49
#
#  선택한 관광지: 감천문화마을
#
#  전체 받은 맛집 수: 75
#
#  주변 맛집 Top 10:
# 1. 웅이네 (23m)
#     부산 사하구 옥천로 125 / ☎ 010-8582-9563
#     카카오맵: http://place.map.kakao.com/890615733
#
# 2. 머거방 (42m)
#     부산 사하구 감내2로 198 / ☎
#     카카오맵: http://place.map.kakao.com/356023586
#
# 3. 찹쌀씨앗호떡 (137m)
#     부산 사하구 감내2로 178 / ☎
#     카카오맵: http://place.map.kakao.com/1550801558
#
# 4. 실비집 (150m)
#     부산 사하구 감내2로 176 / ☎ 051-205-2782
#     카카오맵: http://place.map.kakao.com/25761934
#
# 5. 할매전통돼지껍데기 (179m)
#     부산 서구 아미로 14 / ☎ 051-254-7406
#     카카오맵: http://place.map.kakao.com/2047696186
#
# 6. 김앤서 (180m)
#     부산 사하구 감내2로 132 / ☎
#     카카오맵: http://place.map.kakao.com/1847867680
#
# 7. 감천쫀드기 (181m)
#     부산 사하구 감내2로 136 / ☎
#     카카오맵: http://place.map.kakao.com/2077285742
#
# 8. 감천제빵소 (197m)
#     부산 사하구 감내2로 145 / ☎
#     카카오맵: http://place.map.kakao.com/408500144
#
# 9. 샤르르르 (200m)
#     부산 사하구 감내2로 143-2 / ☎
#     카카오맵: http://place.map.kakao.com/843733807
#
# 10. 츄릅젤라또 (200m)
#     부산 사하구 감내2로 143-2 / ☎
#     카카오맵: http://place.map.kakao.com/624534864
#
#
# 엑셀 파일 저장 완료: 감천문화마을_맛집Top10.xlsx

# %%
import requests
import pandas as pd
import time

# 1️⃣ 구글 플레이스 API - 관광지 검색
def search_google_places(query, api_key):
    url = "https://maps.googleapis.com/maps/api/place/textsearch/json"
    params = {
        'query': f"{query} 관광지",
        'language': 'ko',
        'key': api_key
    }
    res = requests.get(url, params=params)
    if res.status_code != 200:
        print("Google API 실패:", res.status_code)
        return []
    return res.json().get('results', [])

# 2️⃣ 카카오 로컬 API - 맛집 검색
def search_kakao_restaurants(lat, lon, kakao_key):
    url = "https://dapi.kakao.com/v2/local/search/keyword.json"
    headers = {"Authorization": f"KakaoAK {kakao_key}"}
    params = {
        'query': '맛집',
        'x': lon,
        'y': lat,
        'radius': 3000,
        'size': 10
    }
    res = requests.get(url, headers=headers, params=params)
    if res.status_code != 200:
        print("카카오 API 실패:", res.status_code)
        return []
    return res.json().get('documents', [])

# 3️⃣ 전국 데이터 수집
def main():
    GOOGLE_KEY = 'AIzaSyAypFLkcwV_HqxLsTpU8RfkXsYeBG9vetg'
    KAKAO_KEY = '7659c6478eec0d513fc4881bbcd44c2c'

    # ✅ 전국 주요 지역 리스트
    regions = [
        '서울', '부산', '대구', '인천', '광주', '대전', '울산',
        '세종', '경기도', '강원도', '충청북도', '충청남도',
        '전라북도', '전라남도', '경상북도', '경상남도', '제주도'
    ]

    all_data = []

    for region in regions:
        print(f"\n===== {region} 관광지 검색 시작 =====")
        places = search_google_places(region, GOOGLE_KEY)
        if not places:
            print(f"{region} 지역에서 관광지를 찾을 수 없습니다.")
            continue

        for place in places:
            name = place.get('name')
            addr = place.get('formatted_address')
            rating = place.get('rating', 'N/A')
            lat = place['geometry']['location']['lat']
            lon = place['geometry']['location']['lng']

            restaurants = search_kakao_restaurants(lat, lon, KAKAO_KEY)

            for r in restaurants:
                all_data.append({
                    '지역': region,
                    '관광지명': name,
                    '관광지주소': addr,
                    '관광지평점': rating,
                    '맛집명': r.get('place_name'),
                    '맛집주소': r.get('address_name'),
                    '맛집거리(m)': r.get('distance'),
                    '맛집전화번호': r.get('phone')
                })

        time.sleep(1)  # ✅ API Rate Limit 방지 (1초 대기)

    # ✅ 엑셀 저장
    df = pd.DataFrame(all_data)
    file_name = "전국_관광지_맛집리스트.xlsx"
    df.to_excel(file_name, index=False)
    print(f"\n엑셀 파일 저장 완료: {file_name}")

if __name__ == "__main__":
    main()
# Out:
# ===== 서울 관광지 검색 시작 =====
#
# ===== 부산 관광지 검색 시작 =====
#
# ===== 대구 관광지 검색 시작 =====
#
# ===== 인천 관광지 검색 시작 =====
#
# ===== 광주 관광지 검색 시작 =====
#
# ===== 대전 관광지 검색 시작 =====
#
# ===== 울산 관광지 검색 시작 =====
#
# ===== 세종 관광지 검색 시작 =====
#
# ===== 경기도 관광지 검색 시작 =====
#
# ===== 강원도 관광지 검색 시작 =====
#
# ===== 충청북도 관광지 검색 시작 =====
#
# ===== 충청남도 관광지 검색 시작 =====
#
# ===== 전라북도 관광지 검색 시작 =====
#
# ===== 전라남도 관광지 검색 시작 =====
#
# ===== 경상북도 관광지 검색 시작 =====
#
# ===== 경상남도 관광지 검색 시작 =====
#
# ===== 제주도 관광지 검색 시작 =====
#
# 엑셀 파일 저장 완료: 전국_관광지_맛집리스트.xlsx

# %%
import requests
import pandas as pd
import time

def search_google_places(query, api_key):
    url = "https://maps.googleapis.com/maps/api/place/textsearch/json"
    params = {
        'query': query + " 관광지",
        'language': 'ko',
        'key': api_key
    }
    res = requests.get(url, params=params)
    if res.status_code != 200:
        print("Google API 실패:", res.status_code)
        return []
    return res.json().get('results', [])

def search_kakao_restaurants(lat, lon, api_key, pages=3):
    url = "https://dapi.kakao.com/v2/local/search/category.json"
    headers = {"Authorization": api_key}
    all_restaurants = []

    for page in range(1, pages + 1):
        params = {
            'category_group_code': 'FD6',
            'x': str(lon),
            'y': str(lat),
            'radius': 3000,
            'size': 15,
            'page': page,
            'sort': 'distance'
        }
        res = requests.get(url, headers=headers, params=params)
        if res.status_code != 200:
            print("카카오 API 실패:", res.status_code)
            continue
        all_restaurants += res.json().get('documents', [])

    return all_restaurants

# === 전국 실행 ===
GOOGLE_API_KEY = 'AIzaSyAypFLkcwV_HqxLsTpU8RfkXsYeBG9vetg'
KAKAO_API_KEY = 'KakaoAK 7659c6478eec0d513fc4881bbcd44c2c'

regions = [
    '서울', '부산', '대구', '인천', '광주', '대전', '울산',
    '세종', '경기도', '강원도', '충청북도', '충청남도',
    '전라북도', '전라남도', '경상북도', '경상남도', '제주도'
]

all_data = []

for region in regions:
    print(f"\n===== {region} 관광지 검색 시작 =====")
    places = search_google_places(region, GOOGLE_API_KEY)
    if not places:
        print(f"{region} 관광지를 찾을 수 없습니다.")
        continue

    for place in places:
        name = place.get('name')
        addr = place.get('formatted_address')
        rating = place.get('rating', 'N/A')
        lat = place['geometry']['location']['lat']
        lon = place['geometry']['location']['lng']

        # 맛집 검색
        restaurants = search_kakao_restaurants(lat, lon, KAKAO_API_KEY, pages=5)
        valid_restaurants = [r for r in restaurants if r.get('place_name')]

        # 거리순 정렬 Top 10
        sorted_restaurants = sorted(
            valid_restaurants,
            key=lambda x: int(x.get('distance', 99999))
        )[:10]

        for r in sorted_restaurants:
            all_data.append({
                '지역': region,
                '관광지명': name,
                '관광지주소': addr,
                '관광지평점': rating,
                '맛집명': r['place_name'],
                '맛집주소': r.get('road_address_name', '주소 없음'),
                '맛집거리(m)': r.get('distance', '?'),
                '맛집전화번호': r.get('phone', '정보 없음'),
                '카카오맵 URL': r.get('place_url', '없음')
            })

    time.sleep(1)  # ✅ API 호출 속도 조절

# ✅ 전국 엑셀 저장
df = pd.DataFrame(all_data)
file_name = "전국_관광지_맛집Top10.xlsx"
df.to_excel(file_name, index=False)
print(f"\n전국 엑셀 파일 저장 완료: {file_name}")
# Out:
# ===== 서울 관광지 검색 시작 =====
#
# ===== 부산 관광지 검색 시작 =====
#
# ===== 대구 관광지 검색 시작 =====
#
# ===== 인천 관광지 검색 시작 =====
#
# ===== 광주 관광지 검색 시작 =====
#
# ===== 대전 관광지 검색 시작 =====
#
# ===== 울산 관광지 검색 시작 =====
#
# ===== 세종 관광지 검색 시작 =====
#
# ===== 경기도 관광지 검색 시작 =====
#
# ===== 강원도 관광지 검색 시작 =====
#
# ===== 충청북도 관광지 검색 시작 =====
#
# ===== 충청남도 관광지 검색 시작 =====
#
# ===== 전라북도 관광지 검색 시작 =====
#
# ===== 전라남도 관광지 검색 시작 =====
#
# ===== 경상북도 관광지 검색 시작 =====
#
# ===== 경상남도 관광지 검색 시작 =====
#
# ===== 제주도 관광지 검색 시작 =====
#
# 전국 엑셀 파일 저장 완료: 전국_관광지_맛집Top10.xlsx
